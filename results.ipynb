# %%
# Imports
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gram-Schmidt QR Factorization
#
# The list entries were copied from the generated `out/results.txt` file

# %%
dimensions = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000, 4000, 5000]
c_orthogonality = [8.15066e-14, 4.6161, 3.7716, 3.05451, 2.68287, 2.58839, 2.25456, 2.03113, 1.93039, 1.8155, 1.47168, 1.287, 1.22033, 1.17306]
m_orthogonality = [8.15066e-14, 4.6161, 3.7716, 3.05451, 2.68287, 2.58839, 2.25456, 2.03113, 1.93039, 1.8155, 1.47168, 1.287, 1.22033, 1.17306]

plt.legend("||Q^TQ - I||_1 for test matrices with dimensions 100x___")
plt.yscale("log") 
plt.plot(dimensions, c_orthogonality)
plt.plot(dimensions, m_orthogonality, color='r')

# %%
dimensions = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1500, 2000, 2500]
c_orthogonality = [1.287, 1.83022, 2.52394, 3.29045, 4.08822, 5.07157, 6.11151, 7.35234, 8.50071, 9.31295, 14.9159, 23.217, 33.8078]
m_orthogonality = [1.287, 1.83022, 2.52394, 3.29045, 4.08822, 5.07157, 6.11151, 7.35234, 8.50071, 9.31295, 14.9159, 23.217, 33.8078]



plt.yscale("log") 
plt.plot(dimensions, c_orthogonality)
plt.plot(dimensions, m_orthogonality, color='r')
